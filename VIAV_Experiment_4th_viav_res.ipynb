# %% [markdown]
# # Demo for path context retriever

# %%
import pandas as pd
import json
from path_cont_retr import PathContextRetrieval

# %% [markdown]
# Decision NOTE: due to fu-ref from 2023 from Ilya We need to set this file from 2021 '/lustre/acslab/shared/LLM_stuff/subgraph_retrieval/medline_cooc_graphs/2021_11_22_cooc_graph_titles_mcl.pkl' to retrieve path

# %%
path_cont_retr_obj = PathContextRetrieval(
    config_path='/work/acslab/shared/llm_expl_shared_data/hgcr_config_081924_shared.json'
)
# Out:
# Init ranker model...
# Init node embeddings...
# Init co-occur graph...
# graph-tool network constructed!
# Init context embeddings...
# Using MedCPT
# Opening np chunks: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:01<00:00, 26.17it/s]
# Opening json index chunks: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:02<00:00, 14.31it/s]
# Constructing PMID lookup index: 100%|██████████████████████████████████████████████████████████████████████████████████████████████| 38/38 [00:26<00:00,  1.41it/s]

# %%
path_cont_retr_obj.mcg_obj.pmid_to_ts_dict['20377462']
# Out:
# '2010'

# %%
path_cont_retr_obj.mcg_obj.pmid_to_ts_dict['22293089']
# path_cont_retr_obj.mcg_obj.pmid_to_ts_dict['21187224']
# path_cont_retr_obj.mcg_obj.pmid_to_ts_dict['34164801']
# Out:
# '2012'

# %%
pwd
# Out:
# '/work/acslab/users/svalipou/HGCR'

# %% [markdown]
# ## 2. Verify 4th round result from VIAV:

# %% [markdown]
# ## Function to read .txt file and have it as df for pkl format from row data:

# %%
import pandas as pd
import re
file_path = '/work/acslab/users/svalipou/HGCR/viva_result/4th_txt/responses_with_links_pubmed_viav_4.txt'

# %%
with open(file_path, 'r') as file:
    file_content = file.read()

entries = file_content.strip().split('================================================================================')
questions, prompts, responses, context_pmids, subj_names, obj_names = [], [], [], [], [], []

for entry in entries:
    question_match = re.search(r'Question \d+:', entry)
    prompt_match = re.search(r'Based on your information, please describe how an indirect relationship between (.*?) and (.*?) might exist\.', entry, re.DOTALL)
    response_match = re.search(r'Response:\n(.*?)(?:References:|$)', entry, re.DOTALL)
    references_match = re.findall(r'https://pubmed.ncbi.nlm.nih.gov/(\d+)/', entry)

    if question_match and prompt_match and response_match:
        questions.append(question_match.group(0).strip())
        prompts.append(prompt_match.group(0).strip())
        subj_names.append(prompt_match.group(1).strip())
        obj_names.append(prompt_match.group(2).strip())
        responses.append(response_match.group(1).strip())
        context_pmids.append(references_match)

df = pd.DataFrame({
    'subj_name': subj_names,
    'obj_name': obj_names,
    'prompt': prompts,
    'Response': responses,
    'context_pmids': context_pmids
})

df
# Out:
#            subj_name              obj_name  \
# 0      acetaminophen             CTSL gene
# 1      acetaminophen          EIF2AK4 gene
# 2          adenosine           pheniramine
# 3            ethanol            ATG4B gene
# 4         alfentanil           remimazolam
# ..               ...                   ...
# 237  gambogenic acid  ACTA2 protein, human
# 238      canakinumab          zanubrutinib
# 239      entrectinib            dabrafenib
# 240    larotrectinib            dabrafenib
# 241    pembrolizumab     tisotumab vedotin
#
#                                                 prompt  \
# 0    Based on your information, please describe how...
# 1    Based on your information, please describe how...
# 2    Based on your information, please describe how...
# 3    Based on your information, please describe how...
# 4    Based on your information, please describe how...
# ..                                                 ...
# 237  Based on your information, please describe how...
# 238  Based on your information, please describe how...
# 239  Based on your information, please describe how...
# 240  Based on your information, please describe how...
# 241  Based on your information, please describe how...
#
#                                               Response  \
# 0    An indirect relationship between acetaminophen...
# 1    The indirect relationship between acetaminophe...
# 2    Adenosine and pheniramine may have an indirect...
# 3    The indirect relationship between ethanol and ...
# 4    Alfentanil and remimazolam are both pharmacolo...
# ..                                                 ...
# 237  Gambogenic acid (GNA) has been extensively stu...
# 238  Based on the information provided in the paper...
# 239  Based on the information provided in the paper...
# 240  Based on the information provided in the paper...
# 241  Pembrolizumab is a monoclonal antibody that ta...
#
#                                          context_pmids
# 0    [20377462, 22293089, 33180786, 6697867, 810715...
# 1    [22293089, 20377462, 33180786, 35430857, 66978...
# 2    [22293089, 33180786, 31256712, 8107150, 696096...
# 3    [20377462, 22293089, 32787124, 8843485, 331807...
# 4    [7946858, 7905796, 8242265, 9723968, 17439409,...
# ..                                                 ...
# 237  [37193064, 27025602, 25087947, 23163528, 33180...
# 238  [35430857, 33180786, 30832770, 33266517, 81071...
# 239  [35406565, 35430857, 33180786, 8107150, 332665...
# 240  [35406565, 37533946, 33180786, 33622165, 32452...
# 241  [33180786, 35430857, 8107150, 31256712, 355994...
#
# [242 rows x 5 columns]

# %%
df= pd.read_pickle('df_viav_4.pkl')
df
# Out:
#            subj_name              obj_name  \
# 0      acetaminophen             CTSL gene
# 1      acetaminophen          EIF2AK4 gene
# 2          adenosine           pheniramine
# 3            ethanol            ATG4B gene
# 4         alfentanil           remimazolam
# ..               ...                   ...
# 237  gambogenic acid  ACTA2 protein, human
# 238      canakinumab          zanubrutinib
# 239      entrectinib            dabrafenib
# 240    larotrectinib            dabrafenib
# 241    pembrolizumab     tisotumab vedotin
#
#                                                 prompt  \
# 0    Based on your information, please describe how...
# 1    Based on your information, please describe how...
# 2    Based on your information, please describe how...
# 3    Based on your information, please describe how...
# 4    Based on your information, please describe how...
# ..                                                 ...
# 237  Based on your information, please describe how...
# 238  Based on your information, please describe how...
# 239  Based on your information, please describe how...
# 240  Based on your information, please describe how...
# 241  Based on your information, please describe how...
#
#                                               Response  \
# 0    An indirect relationship between acetaminophen...
# 1    The indirect relationship between acetaminophe...
# 2    Adenosine and pheniramine may have an indirect...
# 3    The indirect relationship between ethanol and ...
# 4    Alfentanil and remimazolam are both pharmacolo...
# ..                                                 ...
# 237  Gambogenic acid (GNA) has been extensively stu...
# 238  Based on the information provided in the paper...
# 239  Based on the information provided in the paper...
# 240  Based on the information provided in the paper...
# 241  Pembrolizumab is a monoclonal antibody that ta...
#
#                                          context_pmids
# 0    [20377462, 22293089, 33180786, 6697867, 810715...
# 1    [22293089, 20377462, 33180786, 35430857, 66978...
# 2    [22293089, 33180786, 31256712, 8107150, 696096...
# 3    [20377462, 22293089, 32787124, 8843485, 331807...
# 4    [7946858, 7905796, 8242265, 9723968, 17439409,...
# ..                                                 ...
# 237  [37193064, 27025602, 25087947, 23163528, 33180...
# 238  [35430857, 33180786, 30832770, 33266517, 81071...
# 239  [35406565, 35430857, 33180786, 8107150, 332665...
# 240  [35406565, 37533946, 33180786, 33622165, 32452...
# 241  [33180786, 35430857, 8107150, 31256712, 355994...
#
# [242 rows x 5 columns]

# %%
df = pd.read_pickle('/work/acslab/users/svalipou/HGCR/df_viav_4.pkl')
df
# Out:
#            subj_name              obj_name  \
# 0      pembrolizumab     tisotumab vedotin
# 1      larotrectinib            dabrafenib
# 2        entrectinib            dabrafenib
# 3        canakinumab          zanubrutinib
# 4    gambogenic acid  ACTA2 protein, human
# ..               ...                   ...
# 251       alfentanil           remimazolam
# 252          ethanol            ATG4B gene
# 253        adenosine           pheniramine
# 254    acetaminophen          EIF2AK4 gene
# 255    acetaminophen             CTSL gene
#
#                                                 prompt  \
# 0    Based on your information, please describe how...
# 1    Based on your information, please describe how...
# 2    Based on your information, please describe how...
# 3    Based on your information, please describe how...
# 4    Based on your information, please describe how...
# ..                                                 ...
# 251  Based on your information, please describe how...
# 252  Based on your information, please describe how...
# 253  Based on your information, please describe how...
# 254  Based on your information, please describe how...
# 255  Based on your information, please describe how...
#
#                                               Response  \
# 0    Pembrolizumab is a monoclonal antibody that ta...
# 1    Based on the information provided in the paper...
# 2    Indirectly linking entrectinib and dabrafenib ...
# 3    Canakinumab, an interleukin-1β inhibitor, has ...
# 4    Gambogenic acid (GEA) has been studied for its...
# ..                                                 ...
# 251  Based on the information provided in the paper...
# 252  The indirect relationship between ethanol and ...
# 253  An indirect relationship between adenosine and...
# 254  The papers provided offer insights into the po...
# 255  An indirect relationship between acetaminophen...
#
#                                          context_pmids
# 0    [33180786, 35430857, 8107150, 31256712, 355994...
# 1    [35406565, 37533946, 33180786, 33622165, 32452...
# 2    [35406565, 35430857, 33180786, 8107150, 332665...
# 3    [35430857, 33180786, 30832770, 33266517, 81071...
# 4    [37193064, 27025602, 25087947, 23163528, 33180...
# ..                                                 ...
# 251  [7946858, 7905796, 8242265, 9723968, 17439409,...
# 252  [20377462, 22293089, 32787124, 8843485, 331807...
# 253  [22293089, 33180786, 31256712, 8107150, 696096...
# 254  [22293089, 20377462, 33180786, 35430857, 66978...
# 255  [20377462, 22293089, 33180786, 6697867, 810715...
#
# [256 rows x 5 columns]

# %% [markdown]
# ### Apply function to get the most updatest publication date from .json file.

# %%
with open("/work/acslab/users/svalipou/HGCR/viva_result/pmid_to_yr_010725_dict.json", "r") as f:
    pmid_to_date = json.load(f)
def get_publication_dates(pmid_list):
    return [pmid_to_date.get(str(pmid), "Unknown") for pmid in pmid_list]
df['context_pmids_pub_date_updated'] = df['context_pmids'].apply(get_publication_dates)

df.to_pickle('most_updated_dataframe_with_pub_dates_4th_times.pkl')
df
# Out:
#            subj_name              obj_name  \
# 0      acetaminophen             CTSL gene
# 1      acetaminophen          EIF2AK4 gene
# 2          adenosine           pheniramine
# 3            ethanol            ATG4B gene
# 4         alfentanil           remimazolam
# ..               ...                   ...
# 237  gambogenic acid  ACTA2 protein, human
# 238      canakinumab          zanubrutinib
# 239      entrectinib            dabrafenib
# 240    larotrectinib            dabrafenib
# 241    pembrolizumab     tisotumab vedotin
#
#                                                 prompt  \
# 0    Based on your information, please describe how...
# 1    Based on your information, please describe how...
# 2    Based on your information, please describe how...
# 3    Based on your information, please describe how...
# 4    Based on your information, please describe how...
# ..                                                 ...
# 237  Based on your information, please describe how...
# 238  Based on your information, please describe how...
# 239  Based on your information, please describe how...
# 240  Based on your information, please describe how...
# 241  Based on your information, please describe how...
#
#                                               Response  \
# 0    An indirect relationship between acetaminophen...
# 1    The indirect relationship between acetaminophe...
# 2    Adenosine and pheniramine may have an indirect...
# 3    The indirect relationship between ethanol and ...
# 4    Alfentanil and remimazolam are both pharmacolo...
# ..                                                 ...
# 237  Gambogenic acid (GNA) has been extensively stu...
# 238  Based on the information provided in the paper...
# 239  Based on the information provided in the paper...
# 240  Based on the information provided in the paper...
# 241  Pembrolizumab is a monoclonal antibody that ta...
#
#                                          context_pmids  \
# 0    [20377462, 22293089, 33180786, 6697867, 810715...
# 1    [22293089, 20377462, 33180786, 35430857, 66978...
# 2    [22293089, 33180786, 31256712, 8107150, 696096...
# 3    [20377462, 22293089, 32787124, 8843485, 331807...
# 4    [7946858, 7905796, 8242265, 9723968, 17439409,...
# ..                                                 ...
# 237  [37193064, 27025602, 25087947, 23163528, 33180...
# 238  [35430857, 33180786, 30832770, 33266517, 81071...
# 239  [35406565, 35430857, 33180786, 8107150, 332665...
# 240  [35406565, 37533946, 33180786, 33622165, 32452...
# 241  [33180786, 35430857, 8107150, 31256712, 355994...
#
#                         context_pmids_pub_date_updated
# 0    [2010, 2012, 2020, 1984, 1993, 1997, 2014, 202...
# 1    [2012, 2010, 2020, 2022, 1984, 1993, 1997, 201...
# 2    [2012, 2020, 2019, 1993, 1982, 2014, 2010, 199...
# 3    [2010, 2012, 2020, 1996, 2020, 1994, 2022, 199...
# 4    [1994, 1993, 1993, 1998, 2007, 2020, 1988, 198...
# ..                                                 ...
# 237  [2022, 2015, 2014, 2012, 2020, 2008, 1996, 202...
# 238  [2022, 2020, 2018, 2020, 1993, 2019, 2014, 201...
# 239  [2022, 2022, 2020, 1993, 2020, 2014, 2010, 202...
# 240  [2022, 2023, 2020, 2021, 2019, 1993, 2023, 201...
# 241  [2020, 2022, 1993, 2019, 2022, 2014, 2023, 202...
#
# [242 rows x 6 columns]

# %%
def has_date_greater_than_2021(dates_list):
    return any(int(date) > 2021 for date in dates_list)
filtered_df = df[df['context_pmids_pub_date_updated'].apply(has_date_greater_than_2021)]
filtered_df
# Out:
#            subj_name              obj_name  \
# 0      acetaminophen             CTSL gene
# 1      acetaminophen          EIF2AK4 gene
# 2          adenosine           pheniramine
# 3            ethanol            ATG4B gene
# 5       F3 wt Allele   Alzheimer's Disease
# ..               ...                   ...
# 237  gambogenic acid  ACTA2 protein, human
# 238      canakinumab          zanubrutinib
# 239      entrectinib            dabrafenib
# 240    larotrectinib            dabrafenib
# 241    pembrolizumab     tisotumab vedotin
#
#                                                 prompt  \
# 0    Based on your information, please describe how...
# 1    Based on your information, please describe how...
# 2    Based on your information, please describe how...
# 3    Based on your information, please describe how...
# 5    Based on your information, please describe how...
# ..                                                 ...
# 237  Based on your information, please describe how...
# 238  Based on your information, please describe how...
# 239  Based on your information, please describe how...
# 240  Based on your information, please describe how...
# 241  Based on your information, please describe how...
#
#                                               Response  \
# 0    An indirect relationship between acetaminophen...
# 1    The indirect relationship between acetaminophe...
# 2    Adenosine and pheniramine may have an indirect...
# 3    The indirect relationship between ethanol and ...
# 5    The papers provide insights into the relations...
# ..                                                 ...
# 237  Gambogenic acid (GNA) has been extensively stu...
# 238  Based on the information provided in the paper...
# 239  Based on the information provided in the paper...
# 240  Based on the information provided in the paper...
# 241  Pembrolizumab is a monoclonal antibody that ta...
#
#                                          context_pmids  \
# 0    [20377462, 22293089, 33180786, 6697867, 810715...
# 1    [22293089, 20377462, 33180786, 35430857, 66978...
# 2    [22293089, 33180786, 31256712, 8107150, 696096...
# 3    [20377462, 22293089, 32787124, 8843485, 331807...
# 5    [27357286, 18086003, 25426068, 8871952, 193871...
# ..                                                 ...
# 237  [37193064, 27025602, 25087947, 23163528, 33180...
# 238  [35430857, 33180786, 30832770, 33266517, 81071...
# 239  [35406565, 35430857, 33180786, 8107150, 332665...
# 240  [35406565, 37533946, 33180786, 33622165, 32452...
# 241  [33180786, 35430857, 8107150, 31256712, 355994...
#
#                         context_pmids_pub_date_updated
# 0    [2010, 2012, 2020, 1984, 1993, 1997, 2014, 202...
# 1    [2012, 2010, 2020, 2022, 1984, 1993, 1997, 201...
# 2    [2012, 2020, 2019, 1993, 1982, 2014, 2010, 199...
# 3    [2010, 2012, 2020, 1996, 2020, 1994, 2022, 199...
# 5    [2016, 2007, 2014, 1996, 2009, 2014, 2022, 201...
# ..                                                 ...
# 237  [2022, 2015, 2014, 2012, 2020, 2008, 1996, 202...
# 238  [2022, 2020, 2018, 2020, 1993, 2019, 2014, 201...
# 239  [2022, 2022, 2020, 1993, 2020, 2014, 2010, 202...
# 240  [2022, 2023, 2020, 2021, 2019, 1993, 2023, 201...
# 241  [2020, 2022, 1993, 2019, 2022, 2014, 2023, 202...
#
# [136 rows x 6 columns]

# %%
filtered_df.to_pickle('filtered_viav_df_4th_2022_136_rows.pkl')

# %%
def count_dates_greater_than_2020(dates_list):
    return sum(int(date) > 2021 for date in dates_list)

df['count_publication_date_higher'] = df['context_pmids_pub_date_updated'].apply(count_dates_greater_than_2020)
filtered_df = df[df['count_publication_date_higher'] > 0]
filtered_df
# Out:
#            subj_name              obj_name  \
# 0      acetaminophen             CTSL gene
# 1      acetaminophen          EIF2AK4 gene
# 2          adenosine           pheniramine
# 3            ethanol            ATG4B gene
# 5       F3 wt Allele   Alzheimer's Disease
# ..               ...                   ...
# 237  gambogenic acid  ACTA2 protein, human
# 238      canakinumab          zanubrutinib
# 239      entrectinib            dabrafenib
# 240    larotrectinib            dabrafenib
# 241    pembrolizumab     tisotumab vedotin
#
#                                                 prompt  \
# 0    Based on your information, please describe how...
# 1    Based on your information, please describe how...
# 2    Based on your information, please describe how...
# 3    Based on your information, please describe how...
# 5    Based on your information, please describe how...
# ..                                                 ...
# 237  Based on your information, please describe how...
# 238  Based on your information, please describe how...
# 239  Based on your information, please describe how...
# 240  Based on your information, please describe how...
# 241  Based on your information, please describe how...
#
#                                               Response  \
# 0    An indirect relationship between acetaminophen...
# 1    The indirect relationship between acetaminophe...
# 2    Adenosine and pheniramine may have an indirect...
# 3    The indirect relationship between ethanol and ...
# 5    The papers provide insights into the relations...
# ..                                                 ...
# 237  Gambogenic acid (GNA) has been extensively stu...
# 238  Based on the information provided in the paper...
# 239  Based on the information provided in the paper...
# 240  Based on the information provided in the paper...
# 241  Pembrolizumab is a monoclonal antibody that ta...
#
#                                          context_pmids  \
# 0    [20377462, 22293089, 33180786, 6697867, 810715...
# 1    [22293089, 20377462, 33180786, 35430857, 66978...
# 2    [22293089, 33180786, 31256712, 8107150, 696096...
# 3    [20377462, 22293089, 32787124, 8843485, 331807...
# 5    [27357286, 18086003, 25426068, 8871952, 193871...
# ..                                                 ...
# 237  [37193064, 27025602, 25087947, 23163528, 33180...
# 238  [35430857, 33180786, 30832770, 33266517, 81071...
# 239  [35406565, 35430857, 33180786, 8107150, 332665...
# 240  [35406565, 37533946, 33180786, 33622165, 32452...
# 241  [33180786, 35430857, 8107150, 31256712, 355994...
#
#                         context_pmids_pub_date_updated  \
# 0    [2010, 2012, 2020, 1984, 1993, 1997, 2014, 202...
# 1    [2012, 2010, 2020, 2022, 1984, 1993, 1997, 201...
# 2    [2012, 2020, 2019, 1993, 1982, 2014, 2010, 199...
# 3    [2010, 2012, 2020, 1996, 2020, 1994, 2022, 199...
# 5    [2016, 2007, 2014, 1996, 2009, 2014, 2022, 201...
# ..                                                 ...
# 237  [2022, 2015, 2014, 2012, 2020, 2008, 1996, 202...
# 238  [2022, 2020, 2018, 2020, 1993, 2019, 2014, 201...
# 239  [2022, 2022, 2020, 1993, 2020, 2014, 2010, 202...
# 240  [2022, 2023, 2020, 2021, 2019, 1993, 2023, 201...
# 241  [2020, 2022, 1993, 2019, 2022, 2014, 2023, 202...
#
#      count_publication_date_higher
# 0                                1
# 1                                1
# 2                                1
# 3                                1
# 5                                1
# ..                             ...
# 237                              2
# 238                              1
# 239                              2
# 240                              4
# 241                              3
#
# [136 rows x 7 columns]

# %%
def count_dates_greater_than_2021(dates_list):
    return sum(int(date) > 2021 for date in dates_list)

df['count_publication_date_higher'] = df['context_pmids_pub_date_updated'].apply(count_dates_greater_than_2021)
filtered_df_not_include_2021 = df[df['count_publication_date_higher'] == 0]
filtered_df_not_include_2021
# Out:
#                  subj_name                                        obj_name  \
# 4               alfentanil                                     remimazolam
# 11        Bipolar Disorder                   Thyrotoxic periodic paralysis
# 14             ceftriaxone                                        selenium
# 15   TCF7L2 protein, human                             Cerebral Infarction
# 16     formoterol fumarate                             Bronchitis, Chronic
# ..                     ...                                             ...
# 222              RAC1 gene                                      PARK7 gene
# 223              SOD1 gene                                      SMCR8 gene
# 226            TWIST1 gene  Receptor Tyrosine-Protein Kinase ErbB-4, human
# 228              XPO1 gene                                     YTHDF1 gene
# 230             MLST8 gene                                       ULK2 gene
#
#                                                 prompt  \
# 4    Based on your information, please describe how...
# 11   Based on your information, please describe how...
# 14   Based on your information, please describe how...
# 15   Based on your information, please describe how...
# 16   Based on your information, please describe how...
# ..                                                 ...
# 222  Based on your information, please describe how...
# 223  Based on your information, please describe how...
# 226  Based on your information, please describe how...
# 228  Based on your information, please describe how...
# 230  Based on your information, please describe how...
#
#                                               Response  \
# 4    Alfentanil and remimazolam are both pharmacolo...
# 11   Thyrotoxic periodic paralysis (TPP) and Bipola...
# 14   Ceftriaxone, a commonly used antibiotic, may h...
# 15   The TCF7L2 protein, also known as TCF4, is a t...
# 16   Formoterol fumarate, a potent beta 2-adrenocep...
# ..                                                 ...
# 222  proteins in cellular processes related to mito...
# 223  The indirect relationship between the SOD1 gen...
# 226  Based on the information provided in the paper...
# 228  Based on the information provided in the paper...
# 230  The papers provide insights into inferring cau...
#
#                                          context_pmids  \
# 4    [7946858, 7905796, 8242265, 9723968, 17439409,...
# 11   [2155749, 23291679, 27788314, 8403805, 1189387...
# 14   [1980438, 33180786, 7719737, 23163528, 2229308...
# 15   [10079969, 31709500, 7835145, 1202432, 2165372...
# 16   [7170790, 8568542, 10464898, 19428233, 945891,...
# ..                                                 ...
# 222  [20377462, 21187224, 34781497, 34561450, 22293...
# 223  [20377462, 21187224, 26105819, 33004804, 10405...
# 226                                                 []
# 228  [20377462, 21187224, 24911659, 34781497, 34081...
# 230  [20377462, 21187224, 33004804, 34781497, 20466...
#
#                         context_pmids_pub_date_updated  \
# 4    [1994, 1993, 1993, 1998, 2007, 2020, 1988, 198...
# 11   [1990, 2013, 2015, 1993, 2002, 1998, 2000, 199...
# 14   [1990, 2020, 1994, 2012, 2012, 1986, 2010, 198...
# 15   [1999, 2019, 1994, 1975, 2011, 1982, 2013, 201...
# 16   [1982, 1995, 1999, 2008, 1976, 1986, 2002, 199...
# ..                                                 ...
# 222  [2010, 2010, 2020, 2020, 2012, 2002, 2020, 200...
# 223   [2010, 2010, 2014, 2019, 1999, 2020, 2009, 1997]
# 226                                                 []
# 228  [2010, 2010, 2014, 2020, 2021, 2012, 2002, 200...
# 230  [2010, 2010, 2019, 2020, 2009, 1997, 2016, 202...
#
#      count_publication_date_higher
# 4                                0
# 11                               0
# 14                               0
# 15                               0
# 16                               0
# ..                             ...
# 222                              0
# 223                              0
# 226                              0
# 228                              0
# 230                              0
#
# [106 rows x 7 columns]

# %%
filtered_df_not_include_2021.to_pickle('viav_4_exe_106_rows.pkl')

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['response_length'] = df['Response'].apply(len)
response_length_stats = df['response_length'].describe()

# Step 3: Plot the distribution of string lengths
plt.hist(df['response_length'], bins=20, edgecolor='black')
plt.xlabel('String Length')
plt.ylabel('Frequency')
plt.title('Distribution of Response String Lengths')
plt.show()

# Displaying the summary statistics for the user
response_length_stats
# Out:
# count     256.000000
# mean     2192.957031
# std       520.803318
# min        60.000000
# 25%      1982.250000
# 50%      2200.500000
# 75%      2433.750000
# max      5888.000000
# Name: response_length, dtype: float64

# %%
import pandas as pd

# %%
df = pd.read_pickle('viav_4_exe_106_rows.pkl')
df
# Out:
#                  subj_name                                        obj_name  \
# 4               alfentanil                                     remimazolam
# 11        Bipolar Disorder                   Thyrotoxic periodic paralysis
# 14             ceftriaxone                                        selenium
# 15   TCF7L2 protein, human                             Cerebral Infarction
# 16     formoterol fumarate                             Bronchitis, Chronic
# ..                     ...                                             ...
# 222              RAC1 gene                                      PARK7 gene
# 223              SOD1 gene                                      SMCR8 gene
# 226            TWIST1 gene  Receptor Tyrosine-Protein Kinase ErbB-4, human
# 228              XPO1 gene                                     YTHDF1 gene
# 230             MLST8 gene                                       ULK2 gene
#
#                                                 prompt  \
# 4    Based on your information, please describe how...
# 11   Based on your information, please describe how...
# 14   Based on your information, please describe how...
# 15   Based on your information, please describe how...
# 16   Based on your information, please describe how...
# ..                                                 ...
# 222  Based on your information, please describe how...
# 223  Based on your information, please describe how...
# 226  Based on your information, please describe how...
# 228  Based on your information, please describe how...
# 230  Based on your information, please describe how...
#
#                                               Response  \
# 4    Alfentanil and remimazolam are both pharmacolo...
# 11   Thyrotoxic periodic paralysis (TPP) and Bipola...
# 14   Ceftriaxone, a commonly used antibiotic, may h...
# 15   The TCF7L2 protein, also known as TCF4, is a t...
# 16   Formoterol fumarate, a potent beta 2-adrenocep...
# ..                                                 ...
# 222  proteins in cellular processes related to mito...
# 223  The indirect relationship between the SOD1 gen...
# 226  Based on the information provided in the paper...
# 228  Based on the information provided in the paper...
# 230  The papers provide insights into inferring cau...
#
#                                          context_pmids  \
# 4    [7946858, 7905796, 8242265, 9723968, 17439409,...
# 11   [2155749, 23291679, 27788314, 8403805, 1189387...
# 14   [1980438, 33180786, 7719737, 23163528, 2229308...
# 15   [10079969, 31709500, 7835145, 1202432, 2165372...
# 16   [7170790, 8568542, 10464898, 19428233, 945891,...
# ..                                                 ...
# 222  [20377462, 21187224, 34781497, 34561450, 22293...
# 223  [20377462, 21187224, 26105819, 33004804, 10405...
# 226                                                 []
# 228  [20377462, 21187224, 24911659, 34781497, 34081...
# 230  [20377462, 21187224, 33004804, 34781497, 20466...
#
#                         context_pmids_pub_date_updated  \
# 4    [1994, 1993, 1993, 1998, 2007, 2020, 1988, 198...
# 11   [1990, 2013, 2015, 1993, 2002, 1998, 2000, 199...
# 14   [1990, 2020, 1994, 2012, 2012, 1986, 2010, 198...
# 15   [1999, 2019, 1994, 1975, 2011, 1982, 2013, 201...
# 16   [1982, 1995, 1999, 2008, 1976, 1986, 2002, 199...
# ..                                                 ...
# 222  [2010, 2010, 2020, 2020, 2012, 2002, 2020, 200...
# 223   [2010, 2010, 2014, 2019, 1999, 2020, 2009, 1997]
# 226                                                 []
# 228  [2010, 2010, 2014, 2020, 2021, 2012, 2002, 200...
# 230  [2010, 2010, 2019, 2020, 2009, 1997, 2016, 202...
#
#      count_publication_date_higher
# 4                                0
# 11                               0
# 14                               0
# 15                               0
# 16                               0
# ..                             ...
# 222                              0
# 223                              0
# 226                              0
# 228                              0
# 230                              0
#
# [106 rows x 7 columns]
